# %%
import os

# Create dataset folders
os.makedirs("data/train", exist_ok=True)
os.makedirs("data/test", exist_ok=True)

print("Folder structure created successfully!")
# Out:
# ✅ Folder structure created successfully!

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %%
import os

# Print the contents of the data directory
data_dir = "data"
print("📁 Contents of data folder:")
print(os.listdir(data_dir))
# Out:
# 📁 Contents of data folder:
# ['test', 'train']

# %%
import os

print("Train folders:", os.listdir("data/train"))
print("Test folders:", os.listdir("data/test"))
# Out:
# Train folders: ['angry', 'disgust', 'fear', 'happy']
# Test folders: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
